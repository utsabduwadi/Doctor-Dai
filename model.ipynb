# %%
# !pip install pandas
# !pip install numpy
# !pip install scikit-learn
# Out:
# Requirement already satisfied: pandas in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.22.4 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ankus\appdata\roaming\python\python310\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ankus\appdata\roaming\python\python310\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: numpy in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (2.1.3)
# Requirement already satisfied: scikit-learn in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (1.7.2)
# Requirement already satisfied: numpy>=1.22.0 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (2.1.3)
# Requirement already satisfied: scipy>=1.8.0 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ankus\appdata\local\programs\python\python310\lib\site-packages (from scikit-learn) (3.6.0)

# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report,accuracy_score
from sklearn.metrics import mean_absolute_error
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv(r"C:\python\Doctor-Dai\Training.csv")
df.describe()
# Out:
#            itching    skin_rash  nodal_skin_eruptions  continuous_sneezing  \
# count  4920.000000  4920.000000           4920.000000          4920.000000
# mean      0.137805     0.159756              0.021951             0.045122
# std       0.344730     0.366417              0.146539             0.207593
# min       0.000000     0.000000              0.000000             0.000000
# 25%       0.000000     0.000000              0.000000             0.000000
# 50%       0.000000     0.000000              0.000000             0.000000
# 75%       0.000000     0.000000              0.000000             0.000000
# max       1.000000     1.000000              1.000000             1.000000
#
#          shivering       chills   joint_pain  stomach_pain      acidity  \
# count  4920.000000  4920.000000  4920.000000   4920.000000  4920.000000
# mean      0.021951     0.162195     0.139024      0.045122     0.045122
# std       0.146539     0.368667     0.346007      0.207593     0.207593
# min       0.000000     0.000000     0.000000      0.000000     0.000000
# 25%       0.000000     0.000000     0.000000      0.000000     0.000000
# 50%       0.000000     0.000000     0.000000      0.000000     0.000000
# 75%       0.000000     0.000000     0.000000      0.000000     0.000000
# max       1.000000     1.000000     1.000000      1.000000     1.000000
#
#        ulcers_on_tongue  ...   blackheads     scurring  skin_peeling  \
# count       4920.000000  ...  4920.000000  4920.000000   4920.000000
# mean           0.021951  ...     0.021951     0.021951      0.023171
# std            0.146539  ...     0.146539     0.146539      0.150461
# min            0.000000  ...     0.000000     0.000000      0.000000
# 25%            0.000000  ...     0.000000     0.000000      0.000000
# 50%            0.000000  ...     0.000000     0.000000      0.000000
# 75%            0.000000  ...     0.000000     0.000000      0.000000
# max            1.000000  ...     1.000000     1.000000      1.000000
#
#        silver_like_dusting  small_dents_in_nails  inflammatory_nails  \
# count          4920.000000           4920.000000         4920.000000
# mean              0.023171              0.023171            0.023171
# std               0.150461              0.150461            0.150461
# min               0.000000              0.000000            0.000000
# 25%               0.000000              0.000000            0.000000
# 50%               0.000000              0.000000            0.000000
# 75%               0.000000              0.000000            0.000000
# max               1.000000              1.000000            1.000000
#
#            blister  red_sore_around_nose  yellow_crust_ooze  Unnamed: 133
# count  4920.000000           4920.000000        4920.000000           0.0
# mean      0.023171              0.023171           0.023171           NaN
# std       0.150461              0.150461           0.150461           NaN
# min       0.000000              0.000000           0.000000           NaN
# 25%       0.000000              0.000000           0.000000           NaN
# 50%       0.000000              0.000000           0.000000           NaN
# 75%       0.000000              0.000000           0.000000           NaN
# max       1.000000              1.000000           1.000000           NaN
#
# [8 rows x 133 columns]

# %%
df.shape
# Out:
# (4920, 134)

# %%
df.drop('Unnamed: 133', axis=1, inplace=True)
df.columns
# Out:
# Index(['itching', 'skin_rash', 'nodal_skin_eruptions', 'continuous_sneezing',
#        'shivering', 'chills', 'joint_pain', 'stomach_pain', 'acidity',
#        'ulcers_on_tongue',
#        ...
#        'blackheads', 'scurring', 'skin_peeling', 'silver_like_dusting',
#        'small_dents_in_nails', 'inflammatory_nails', 'blister',
#        'red_sore_around_nose', 'yellow_crust_ooze', 'prognosis'],
#       dtype='object', length=133)

# %%
df['prognosis'].value_counts()
# Out:
# prognosis
# Fungal infection                           120
# Allergy                                    120
# GERD                                       120
# Chronic cholestasis                        120
# Drug Reaction                              120
# Peptic ulcer diseae                        120
# AIDS                                       120
# Diabetes                                   120
# Gastroenteritis                            120
# Bronchial Asthma                           120
# Hypertension                               120
# Migraine                                   120
# Cervical spondylosis                       120
# Paralysis (brain hemorrhage)               120
# Jaundice                                   120
# Malaria                                    120
# Chicken pox                                120
# Dengue                                     120
# Typhoid                                    120
# hepatitis A                                120
# Hepatitis B                                120
# Hepatitis C                                120
# Hepatitis D                                120
# Hepatitis E                                120
# Alcoholic hepatitis                        120
# Tuberculosis                               120
# Common Cold                                120
# Pneumonia                                  120
# Dimorphic hemmorhoids(piles)               120
# Heart attack                               120
# Varicose veins                             120
# Hypothyroidism                             120
# Hyperthyroidism                            120
# Hypoglycemia                               120
# Osteoarthristis                            120
# Arthritis                                  120
# (vertigo) Paroymsal  Positional Vertigo    120
# Acne                                       120
# Urinary tract infection                    120
# Psoriasis                                  120
# Impetigo                                   120
# Name: count, dtype: int64

# %%
x = df.drop('prognosis', axis = 1)
y = df['prognosis']
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=42)

# %%
tree = DecisionTreeClassifier()

# %%
tree.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred = tree.predict(x_test)
acc = tree.score(x_test, y_test)

print("Acurray on test set: {:.2f}%".format(acc*100))
# Out:
# Acurray on test set: 100.00%

# %%
fi = pd.DataFrame(tree.feature_importances_*100, x_test.columns, columns=['Importance'])
fi.sort_values(by='Importance',ascending=False, inplace=True)
fi
# Out:
#                                 Importance
# runny_nose                        2.645294
# internal_itching                  2.638602
# hip_joint_pain                    2.609205
# swollen_extremeties               2.586532
# increased_appetite                2.586360
# ...                                    ...
# history_of_alcohol_consumption    0.000000
# blackheads                        0.000000
# skin_peeling                      0.000000
# small_dents_in_nails              0.000000
# red_sore_around_nose              0.000000
#
# [132 rows x 1 columns]

# %%
zeros = np.array(fi[fi['Importance'] <= 2.300000].index)
zeros
# Out:
# array(['watering_from_eyes', 'spotting_ urination', 'joint_pain',
#        'patches_in_throat', 'yellowing_of_eyes', 'malaise',
#        'family_history', 'stomach_bleeding', 'constipation', 'diarrhoea',
#        'ulcers_on_tongue', 'pus_filled_pimples', 'sweating', 'fatigue',
#        'pain_behind_the_eyes', 'breathlessness', 'chest_pain',
#        'nodal_skin_eruptions', 'chills', 'painful_walking',
#        'inflammatory_nails', 'burning_micturition', 'scurring',
#        'stomach_pain', 'abdominal_pain', 'extra_marital_contacts',
#        'weakness_of_one_body_side', 'dark_urine', 'foul_smell_of urine',
#        'sunken_eyes', 'blister', 'passage_of_gases', 'high_fever',
#        'visual_disturbances', 'irritation_in_anus', 'swollen_legs',
#        'yellowish_skin', 'continuous_sneezing', 'itching', 'skin_rash',
#        'obesity', 'bruising', 'cramps', 'dizziness',
#        'pain_in_anal_region', 'bloody_stool', 'weakness_in_limbs',
#        'pain_during_bowel_movements', 'redness_of_eyes', 'congestion',
#        'sinus_pressure', 'fluid_overload', 'swelled_lymph_nodes',
#        'blurred_and_distorted_vision', 'phlegm', 'throat_irritation',
#        'acute_liver_failure', 'swelling_of_stomach', 'yellow_urine',
#        'weight_gain', 'shivering', 'acidity', 'muscle_wasting',
#        'vomiting', 'cough', 'restlessness', 'lethargy',
#        'irregular_sugar_level', 'headache', 'indigestion', 'dehydration',
#        'loss_of_appetite', 'cold_hands_and_feets', 'anxiety',
#        'mood_swings', 'irritability', 'spinning_movements',
#        'loss_of_balance', 'enlarged_thyroid', 'swollen_blood_vessels',
#        'excessive_hunger', 'brittle_nails', 'slurred_speech',
#        'drying_and_tingling_lips', 'knee_pain', 'muscle_weakness',
#        'stiff_neck', 'swelling_joints', 'puffy_face_and_eyes',
#        'toxic_look_(typhos)', 'bladder_discomfort', 'loss_of_smell',
#        'rusty_sputum', 'mucoid_sputum', 'polyuria',
#        'receiving_blood_transfusion', 'distention_of_abdomen', 'coma',
#        'receiving_unsterile_injections', 'history_of_alcohol_consumption',
#        'blackheads', 'skin_peeling', 'small_dents_in_nails',
#        'red_sore_around_nose'], dtype=object)

# %%
training_new = df.drop(columns=zeros, axis=1)
training_new.shape[1]
training_new.columns
# Out:
# Index(['weight_loss', 'nausea', 'back_pain', 'mild_fever', 'runny_nose',
#        'fast_heart_rate', 'neck_pain', 'swollen_extremeties', 'hip_joint_pain',
#        'movement_stiffness', 'unsteadiness', 'continuous_feel_of_urine',
#        'internal_itching', 'depression', 'muscle_pain', 'altered_sensorium',
#        'red_spots_over_body', 'belly_pain', 'abnormal_menstruation',
#        'dischromic _patches', 'increased_appetite', 'lack_of_concentration',
#        'fluid_overload.1', 'blood_in_sputum', 'prominent_veins_on_calf',
#        'palpitations', 'silver_like_dusting', 'yellow_crust_ooze',
#        'prognosis'],
#       dtype='object')

# %%
def modelling(df1):
    x_new = df1.drop('prognosis', axis = 1)
    y_new = df1.prognosis
    x_train_new, x_test_new, y_train_new, y_test_new = train_test_split(x_new, y_new, test_size=0.3, random_state=42) 
    tree.fit(x_train_new, y_train_new)
    
    pred_new = tree.predict(x_test_new)
    
    acc_new = tree.score(x_test_new, y_test_new)
#     a = mean_absolute_error(y_test_new, pred_new)
    print("Acurray on test set: {:.2f}%".format(acc*100))
#     print("mean_absolute_error of the test set: {:.2f}%".format(a))

# %%
test = pd.read_csv(r"C:\python\Doctor-Dai\Testing.csv")
test_new = test.drop(columns=zeros, axis=1)
test_new.shape[1]
# Out:
# 29

# %%
modelling(test_new)
# Out:
# Acurray on test set: 100.00%
# c:\Users\ankus\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\multiclass.py:213: UserWarning: The number of unique classes is greater than 50% of the number of samples. `y` could represent a regression problem, not a classification problem.
#   y_type = type_of_target(y, input_name="y")

# %%
import pickle

with open("decision_tree_model.pkl", "wb") as f:
    pickle.dump(tree, f, protocol=pickle.HIGHEST_PROTOCOL)
